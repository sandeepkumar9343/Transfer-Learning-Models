# %% [markdown]
# # Transfer Learning - VGG16
#
# Vgg16 is a pretrained model achieves 92.7% top-5 test accuracy on ImageNet dataset which contains 14 million images belonging to 1000 classes.
#
# VGG16 is a convolution neural net (CNN ) architecture which was used to win ILSVR(Imagenet) competition in 2014. It is considered to be one of the excellent vision model architecture till date.
#
#  The 16 in VGG16 refers to it has 16 layers that have weights. This network is a pretty large network and it has about 138 million (approx) parameters.

# %% [markdown]
# <img src='Picture1.jpg' style='width:800px;height:400px'/>

# %% [markdown]
# # Importing Model

# %%
from keras.applications.vgg16 import VGG16
model=VGG16()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Summary

# %%
print(model.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# # Making predictions

# %%
from keras.preprocessing.image import load_img
image=load_img('C:/Users/sandeep/Desktop/INTERNSHIP/data/dog.jpg',target_size=(224,224))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
from keras.preprocessing.image import img_to_array
# convert the image pixels to a numpy array
dog_image = img_to_array(image)

# %%
# reshape data for the model
dog_image = dog_image.reshape((1, dog_image.shape[0], dog_image.shape[1], dog_image.shape[2]))

# %%
from keras.applications.vgg16 import preprocess_input
# prepare the image for the VGG model
dog_image = preprocess_input(dog_image)

# %%
from keras.applications.vgg16 import decode_predictions
# predict the probability across all output classes
yhat = model.predict(dog_image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# Labrador_retriever (97.13%)

# %% [markdown]
# This Model correctly predicts the image as DOG with 97% of probability

# %%
image2 = load_img('C:/Users/sandeep/Desktop/INTERNSHIP/data/Coffee-Mug.jpg', target_size=(224, 224))

# %%
plt.imshow(image2)

# %%
# convert the image pixels to a numpy array
mug_image = img_to_array(image2)
# reshape data for the model
mug_image = mug_image.reshape((1, mug_image.shape[0], mug_image.shape[1], mug_image.shape[2]))
# prepare the image for the VGG model
mug_image = preprocess_input(mug_image)
# predict the probability across all output classes
yhat2 = model.predict(mug_image)
# convert the probabilities to class labels
label2 = decode_predictions(yhat2)
# retrieve the most likely result, e.g. highest probability
label2 = label2[0][0]
# print the classification
print('%s (%.2f%%)' % (label2[1], label2[2]*100))
# Out:
# coffee_mug (75.27%)

# %% [markdown]
# This Model correctly predicts the image as COFFE MUG with 75% of probability

# %%
image3 = load_img('C:/Users/sandeep/Desktop/INTERNSHIP/data/cat.jpg', target_size=(224, 224))

# %%
plt.imshow(image3)

# %%
# convert the image pixels to a numpy array
cat_image = img_to_array(image3)

# reshape data for the model
cat_image = cat_image.reshape((1, cat_image.shape[0], cat_image.shape[1], cat_image.shape[2]))

# prepare the image for the VGG model
cat_image = preprocess_input(cat_image)

# predict the probability across all output classes
yhat3 = model.predict(cat_image)

# convert the probabilities to class labels
label3 = decode_predictions(yhat3)

# retrieve the most likely result, e.g. highest probability
label3 = label3[0][0]
# print the classification
print('%s (%.2f%%)' % (label3[1], label3[2]*100))
# Out:
# tabby (49.20%)

# %% [markdown]
# This Model correctly predicts the image as CAT(tabby) with 49% of probability

# %%
image4 = load_img('C:/Users/sandeep/Desktop/INTERNSHIP/data/elephant.jpg', target_size=(224, 224))

# %%
plt.imshow(image4)

# %%
# convert the image pixels to a numpy array
elephant_image = img_to_array(image4)

# reshape data for the model
elephant_image = elephant_image.reshape((1, elephant_image.shape[0], elephant_image.shape[1], elephant_image.shape[2]))

# prepare the image for the VGG model
elephant_image = preprocess_input(elephant_image)

# predict the probability across all output classes
yhat4 = model.predict(elephant_image)

# convert the probabilities to class labels
label4 = decode_predictions(yhat4)

# retrieve the most likely result, e.g. highest probability
label4 = label4[0][0]
# print the classification
print('%s (%.2f%%)' % (label4[1], label4[2]*100))
# Out:
# African_elephant (92.99%)

# %% [markdown]
# This Model correctly predicts the image as Elephant with 92% of probability
